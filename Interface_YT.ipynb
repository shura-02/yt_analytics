# %%
import streamlit as st

# %%
# read file from a github repository
*** insert code here***

# %%
st.set_page_config(
    page_title = 'Web Interface for YT analytics',
    page_icon = '✅',
    layout = 'wide'
)

# %%
#title
st.title("Youtube Analytics")

# %%
#container1
placeholder = st.empty()
